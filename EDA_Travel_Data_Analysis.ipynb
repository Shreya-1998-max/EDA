# %%
pwd
# Out:
# '/content'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('Travel.csv')

# %%
data.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
data.tail()
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
# ...

# %%
data.sample(6)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 3236      203236          1  34.0  Company Invited         1             36.0
# 4604      204604          0  32.0     Self Enquiry         1             19.0
# 882       200882          0  36.0     Self Enquiry         1              6.0
# 468       200468          0  52.0     Self Enquiry         1             12.0
# 2624      202624          0  32.0     Self Enquiry         1             19.0
# 1492      201492          0  34.0     Self Enquiry         1             13.0
#
#           Occupation   Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 3236  Small Business   Female                       3                5.0
# 4604  Small Business   Female                       3                4.0
# 882   Large Business   Female                       3                5.0
# 468   Large Business     Male                       3                3.0
# ...

# %%
data.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
data.shape
# Out:
# (4888, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
data.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
data.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %%
data.describe().T
# Out:
#                            count           mean          std       min  \
# CustomerID                4888.0  202443.500000  1411.188388  200000.0
# ProdTaken                 4888.0       0.188216     0.390925       0.0
# Age                       4662.0      37.622265     9.316387      18.0
# CityTier                  4888.0       1.654255     0.916583       1.0
# DurationOfPitch           4637.0      15.490835     8.519643       5.0
# NumberOfPersonVisiting    4888.0       2.905074     0.724891       1.0
# NumberOfFollowups         4843.0       3.708445     1.002509       1.0
# PreferredPropertyStar     4862.0       3.581037     0.798009       3.0
# NumberOfTrips             4748.0       3.236521     1.849019       1.0
# Passport                  4888.0       0.290917     0.454232       0.0
# PitchSatisfactionScore    4888.0       3.078151     1.365792       1.0
# OwnCar                    4888.0       0.620295     0.485363       0.0
# ...

# %%
data.isnull()
# Out:
#       CustomerID  ProdTaken    Age  TypeofContact  CityTier  DurationOfPitch  \
# 0          False      False  False          False     False            False
# 1          False      False  False          False     False            False
# 2          False      False  False          False     False            False
# 3          False      False  False          False     False            False
# 4          False      False   True          False     False            False
# ...          ...        ...    ...            ...       ...              ...
# 4883       False      False  False          False     False            False
# 4884       False      False  False          False     False            False
# 4885       False      False  False          False     False            False
# 4886       False      False  False          False     False            False
# 4887       False      False  False          False     False            False
#
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
data.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
missed_values = [fea for fea in data.columns if data[fea].isnull().sum()>0]
missed_values
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
len(missed_values)
# Out:
# 8

# %%
plt.figure(figsize = (9,6))
sns.heatmap(data.isnull(),cbar = True)
# Out:
# <Axes: >

# %%
cat_col = [fea for fea in data.columns if data[fea].dtype=="object"]
cat_col
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
num_col = [fea for fea in data.columns if data[fea].dtype !='object']
num_col
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
cat_data = data[cat_col]
cat_data
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
numeric_data = data[num_col]
numeric_data
# Out:
#       CustomerID  ProdTaken   Age  CityTier  DurationOfPitch  \
# 0         200000          1  41.0         3              6.0
# 1         200001          0  49.0         1             14.0
# 2         200002          1  37.0         1              8.0
# 3         200003          0  33.0         1              9.0
# 4         200004          0   NaN         1              8.0
# ...          ...        ...   ...       ...              ...
# 4883      204883          1  49.0         3              9.0
# 4884      204884          1  28.0         1             31.0
# 4885      204885          1  52.0         3             17.0
# 4886      204886          1  19.0         3             16.0
# 4887      204887          1  36.0         1             14.0
#
#       NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# 0                          3                3.0                    3.0
# 1                          3                4.0                    4.0
# ...

# %%
numeric_data = numeric_data.drop('CustomerID',axis =1)
numeric_data
# Out:
#       ProdTaken   Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0             1  41.0         3              6.0                       3
# 1             0  49.0         1             14.0                       3
# 2             1  37.0         1              8.0                       3
# 3             0  33.0         1              9.0                       2
# 4             0   NaN         1              8.0                       2
# ...         ...   ...       ...              ...                     ...
# 4883          1  49.0         3              9.0                       3
# 4884          1  28.0         1             31.0                       4
# 4885          1  52.0         3             17.0                       4
# 4886          1  19.0         3             16.0                       3
# 4887          1  36.0         1             14.0                       4
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler,MinMaxScaler
le = LabelEncoder()

# %%
standard_scaler = StandardScaler()
X_standard_scaled = standard_scaler.fit_transform(numeric_data)
X_standard_scaled
# Out:
# array([[ 2.07678682,  0.36259734,  1.46836869, ...,  0.78239198,
#         -1.38412819, -0.48825181],
#        [-0.48151307,  1.22139144, -0.71387094, ...,  0.78239198,
#          0.94749317, -0.64865714],
#        [ 2.07678682, -0.0667997 , -0.71387094, ..., -1.27813172,
#         -1.38412819, -1.21370026],
#        ...,
#        [ 2.07678682,  1.54343922,  1.46836869, ...,  0.78239198,
#          2.11330385,  1.5241567 ],
#        [ 2.07678682, -1.99908641,  1.46836869, ..., -1.27813172,
#          0.94749317, -0.6191039 ],
#        [ 2.07678682, -0.17414896, -0.71387094, ...,  0.78239198,
#          0.94749317,  0.07827827]])

# %%
numeric_data.describe()
# Out:
#          ProdTaken          Age     CityTier  DurationOfPitch  \
# count  4888.000000  4662.000000  4888.000000      4637.000000
# mean      0.188216    37.622265     1.654255        15.490835
# std       0.390925     9.316387     0.916583         8.519643
# min       0.000000    18.000000     1.000000         5.000000
# 25%       0.000000    31.000000     1.000000         9.000000
# 50%       0.000000    36.000000     1.000000        13.000000
# 75%       0.000000    44.000000     3.000000        20.000000
# max       1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# std                  0.724891           1.002509               0.798009
# min                  1.000000           1.000000               3.000000
# ...

# %%
df_standard_scaled = pd.DataFrame(X_standard_scaled,columns =numeric_data.columns)
df_standard_scaled
# Out:
#       ProdTaken       Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0      2.076787  0.362597  1.468369        -1.114115                0.130966
# 1     -0.481513  1.221391 -0.713871        -0.175007                0.130966
# 2      2.076787 -0.066800 -0.713871        -0.879338                0.130966
# 3     -0.481513 -0.496197 -0.713871        -0.761949               -1.248694
# 4     -0.481513       NaN -0.713871        -0.879338               -1.248694
# ...         ...       ...       ...              ...                     ...
# 4883   2.076787  1.221391  1.468369        -0.761949                0.130966
# 4884   2.076787 -1.032943 -0.713871         1.820597                1.510626
# 4885   2.076787  1.543439  1.468369         0.177159                1.510626
# 4886   2.076787 -1.999086  1.468369         0.059770                0.130966
# 4887   2.076787 -0.174149 -0.713871        -0.175007                1.510626
#
# ...

# %%
df_standard_scaled.head(10)
# Out:
#    ProdTaken       Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0   2.076787  0.362597  1.468369        -1.114115                0.130966
# 1  -0.481513  1.221391 -0.713871        -0.175007                0.130966
# 2   2.076787 -0.066800 -0.713871        -0.879338                0.130966
# 3  -0.481513 -0.496197 -0.713871        -0.761949               -1.248694
# 4  -0.481513       NaN -0.713871        -0.879338               -1.248694
# 5  -0.481513 -0.603546 -0.713871        -0.879338                0.130966
# 6  -0.481513  2.294884 -0.713871        -0.761949               -1.248694
# 7  -0.481513 -0.818245 -0.713871         1.703209                0.130966
# 8  -0.481513  0.040550 -0.713871         1.585820               -1.248694
# 9  -0.481513 -0.174149 -0.713871         2.055374                0.130966
#
#    NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# 0          -0.706745              -0.728183      -1.209699  1.561221
# ...

# %%
df_standard_scaled.describe()
# Out:
#           ProdTaken           Age      CityTier  DurationOfPitch  \
# count  4.888000e+03  4.662000e+03  4.888000e+03     4.637000e+03
# mean  -2.907294e-18  2.987267e-16 -2.834612e-17    -3.677599e-17
# std    1.000102e+00  1.000107e+00  1.000102e+00     1.000108e+00
# min   -4.815131e-01 -2.106436e+00 -7.138709e-01    -1.231503e+00
# 25%   -4.815131e-01 -7.108953e-01 -7.138709e-01    -7.619492e-01
# 50%   -4.815131e-01 -1.741490e-01 -7.138709e-01    -2.923953e-01
# 75%   -4.815131e-01  6.846451e-01  1.468369e+00     5.293240e-01
# max    2.076787e+00  2.509583e+00  1.468369e+00     1.308989e+01
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count            4.888000e+03       4.843000e+03           4.862000e+03
# mean             1.860668e-16      -9.389786e-17           5.736076e-17
# std              1.000102e+00       1.000103e+00           1.000103e+00
# min             -2.628353e+00      -2.701947e+00          -7.281830e-01
# ...

# %%
X_minmax_scaled = MinMaxScaler().fit_transform(numeric_data)
X_minmax_scaled
# Out:
# array([[1.        , 0.53488372, 1.        , ..., 1.        , 0.        ,
#         0.20468273],
#        [0.        , 0.72093023, 0.        , ..., 1.        , 0.66666667,
#         0.19584758],
#        [1.        , 0.44186047, 0.        , ..., 0.        , 0.        ,
#         0.16472491],
#        ...,
#        [1.        , 0.79069767, 1.        , ..., 1.        , 1.        ,
#         0.31552653],
#        [1.        , 0.02325581, 1.        , ..., 0.        , 0.66666667,
#         0.19747538],
#        [1.        , 0.41860465, 0.        , ..., 1.        , 0.66666667,
#         0.2358873 ]])

# %%
df_standard_scaled = pd.DataFrame(X_minmax_scaled,columns=numeric_data.columns)
df_standard_scaled
# Out:
#       ProdTaken       Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0           1.0  0.534884       1.0         0.008197                    0.50
# 1           0.0  0.720930       0.0         0.073770                    0.50
# 2           1.0  0.441860       0.0         0.024590                    0.50
# 3           0.0  0.348837       0.0         0.032787                    0.25
# 4           0.0       NaN       0.0         0.024590                    0.25
# ...         ...       ...       ...              ...                     ...
# 4883        1.0  0.720930       1.0         0.032787                    0.50
# 4884        1.0  0.232558       0.0         0.213115                    0.75
# 4885        1.0  0.790698       1.0         0.098361                    0.75
# 4886        1.0  0.023256       1.0         0.090164                    0.50
# 4887        1.0  0.418605       0.0         0.073770                    0.75
#
# ...

# %%
numeric_data.corr()
# Out:
#                           ProdTaken       Age  CityTier  DurationOfPitch  \
# ProdTaken                  1.000000 -0.147254  0.086852         0.078257
# Age                       -0.147254  1.000000 -0.015625        -0.012063
# CityTier                   0.086852 -0.015625  1.000000         0.022703
# DurationOfPitch            0.078257 -0.012063  0.022703         1.000000
# NumberOfPersonVisiting     0.009627  0.011621 -0.001671         0.065141
# NumberOfFollowups          0.112171 -0.002577  0.023652         0.009434
# PreferredPropertyStar      0.099577 -0.010474 -0.009164        -0.006637
# NumberOfTrips              0.018898  0.184905 -0.029709         0.009715
# Passport                   0.260844  0.033399  0.001793         0.033034
# PitchSatisfactionScore     0.051394  0.018510 -0.042160        -0.002880
# OwnCar                    -0.011508  0.048654  0.003817        -0.001626
# NumberOfChildrenVisiting   0.007421  0.007370  0.000672         0.031408
# ...

# %%
numeric_data.cov()
# Out:
#                            ProdTaken           Age    CityTier  \
# ProdTaken                   0.152822     -0.535959    0.031120
# Age                        -0.535959     86.795067   -0.134168
# CityTier                    0.031120     -0.134168    0.840125
# DurationOfPitch             0.260897     -0.944440    0.176544
# NumberOfPersonVisiting      0.002728      0.078126   -0.001110
# NumberOfFollowups           0.043969     -0.024058    0.021716
# PreferredPropertyStar       0.031050     -0.077447   -0.006707
# NumberOfTrips               0.013743      3.158372   -0.050474
# Passport                    0.046318      0.141269    0.000747
# PitchSatisfactionScore      0.027440      0.235235   -0.052778
# OwnCar                     -0.002184      0.220050    0.001698
# NumberOfChildrenVisiting    0.002494      0.058470    0.000529
# MonthlyIncome            -276.097744  23365.183349  255.945958
#
#                           DurationOfPitch  NumberOfPersonVisiting  \
# ...

# %%
numeric_data
# Out:
#       ProdTaken   Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0             1  41.0         3              6.0                       3
# 1             0  49.0         1             14.0                       3
# 2             1  37.0         1              8.0                       3
# 3             0  33.0         1              9.0                       2
# 4             0   NaN         1              8.0                       2
# ...         ...   ...       ...              ...                     ...
# 4883          1  49.0         3              9.0                       3
# 4884          1  28.0         1             31.0                       4
# 4885          1  52.0         3             17.0                       4
# 4886          1  19.0         3             16.0                       3
# 4887          1  36.0         1             14.0                       4
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# ...

# %%
sns.distplot(numeric_data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(numeric_data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
cat_data['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
cat_data['Gender']=cat_data['Gender'].replace({'Fe Male':'Female'})

# %%
cat_data['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 4883      Male
# 4884      Male
# 4885    Female
# 4886      Male
# 4887      Male
# Name: Gender, Length: 4888, dtype: object

# %%
cat_data['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
cat_data
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
sns.countplot(cat_data['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
plt.figure(figsize=(10,8))
sns.heatmap(numeric_data.corr(),cmap='YlOrBr')
# Out:
# <Axes: >

# %%
cat_data
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
cat_col
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
cat_data.isnull().sum()
# Out:
# TypeofContact     25
# Occupation         0
# Gender             0
# ProductPitched     0
# MaritalStatus      0
# Designation        0
# dtype: int64

# %%
x = cat_data.fillna(cat_data.mode().iloc[0])
x
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
cat_data['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
x.isnull().sum()
# Out:
# TypeofContact     0
# Occupation        0
# Gender            0
# ProductPitched    0
# MaritalStatus     0
# Designation       0
# dtype: int64

# %%
x_encoded = pd.get_dummies(x,drop_first=True)
x_encoded
# Out:
#       TypeofContact_Self Enquiry  Occupation_Large Business  \
# 0                           True                      False
# 1                          False                      False
# 2                           True                      False
# 3                          False                      False
# 4                           True                      False
# ...                          ...                        ...
# 4883                        True                      False
# 4884                       False                      False
# 4885                        True                      False
# 4886                        True                      False
# 4887                        True                      False
#
#       Occupation_Salaried  Occupation_Small Business  Gender_Male  \
# 0                    True                      False        False
# 1                    True                      False         True
# ...

# %%
x_encoded = pd.get_dummies(x,drop_first=True)

# %%
x_encoded
# Out:
#       TypeofContact_Self Enquiry  Occupation_Large Business  \
# 0                           True                      False
# 1                          False                      False
# 2                           True                      False
# 3                          False                      False
# 4                           True                      False
# ...                          ...                        ...
# 4883                        True                      False
# 4884                       False                      False
# 4885                        True                      False
# 4886                        True                      False
# 4887                        True                      False
#
#       Occupation_Salaried  Occupation_Small Business  Gender_Male  \
# 0                    True                      False        False
# 1                    True                      False         True
# ...

# %%
cat_data['Occupation'].value_counts()
# Out:
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64

# %%
le =LabelEncoder()
le.fit(x['Occupation'])
# Out:
# LabelEncoder()

# %%
list(le.classes_)
# Out:
# ['Free Lancer', 'Large Business', 'Salaried', 'Small Business']

# %%
occ=le.transform(x['Occupation'])
occ
# Out:
# array([2, 2, 0, ..., 2, 3, 2])

# %%
cat_data['Occupation'] = cat_data['Occupation'].str.strip().str.title()  # Removes extra spaces and capitalizes nicely
# Fix inconsistent entries
cat_data['Occupation'] = cat_data['Occupation'].replace({'Free Lancer': 'Freelancer'})

# %%
cat_data['Occupation'].dtype
# Out:
# dtype('O')

# %%
# Get the mapping of classes to numerical labels
dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
# Out:
# {'Freelancer': np.int64(0),
#  'Large Business': np.int64(1),
#  'Salaried': np.int64(2),
#  'Small Business': np.int64(3)}
